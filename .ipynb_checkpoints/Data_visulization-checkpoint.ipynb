# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv("dataset_cleaned.csv")
print("loaded")
df.head()
# Out:
# loaded
#    id   age  daily_screen_time_hours  social_media_hours  gaming_hours  \
# 0   0  24.0                     7.60                1.83          1.59
# 1   1  19.0                     5.97                1.08          1.50
# 2   2  18.0                     5.09                2.50          1.50
# 3   3  21.0                     6.42                1.26          1.42
# 4   4  26.0                    11.20                1.87          2.81
#
#    work_study_hours  sleep_hours  notifications_per_day  app_opens_per_day  \
# 0              2.11         7.46                  122.0               38.0
# 1              3.03         8.22                   76.0               19.0
# 2              2.40         6.25                  134.0               60.0
# 3              3.36         8.85                  112.0               94.0
# 4              1.95         5.25                  145.9              102.6
#
#    weekend_screen_time  gender  stress_level  academic_work_impact  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'age', 'daily_screen_time_hours', 'social_media_hours',
#        'gaming_hours', 'work_study_hours', 'sleep_hours',
#        'notifications_per_day', 'app_opens_per_day', 'weekend_screen_time',
#        'gender', 'stress_level', 'academic_work_impact', 'addicted_label'],
#       dtype='str')

# %%
corr=df[['daily_screen_time_hours', 'social_media_hours','gaming_hours', 'work_study_hours', 'sleep_hours','notifications_per_day', 'app_opens_per_day', 'weekend_screen_time']].corr(method="pearson")
co=sns.heatmap(corr,annot=False,vmin=-1, vmax=1, center=0,)

# %%
plt.scatter(df["social_media_hours"],df["gaming_hours"])
plt.show()

# %%
df[["academic_work_impact","addicted_label"]].corr()
# Out:
#                       academic_work_impact  addicted_label
# academic_work_impact              1.000000       -0.003249
# addicted_label                   -0.003249        1.000000

# %%
stress=df["stress_level"]
stress[df["addicted_label"]==1].value_counts()
# Out:
# stress_level
# 2    196236
# 0    147767
# 1    146471
# Name: count, dtype: int64

# %%
stress=df["stress_level"]
stress[df["addicted_label"]==0].value_counts()
# Out:
# stress_level
# 2    79785
# 1    61094
# 0    60016
# Name: count, dtype: int64

# %%
gender=df["gender"]
gender[df["addicted_label"]==1].value_counts()
# Out:
# gender
# 1    182331
# 2    155967
# 0    152176
# Name: count, dtype: int64

# %%
gender=df["gender"]
gender[df["addicted_label"]==0].value_counts()
# Out:
# gender
# 1    70365
# 2    65628
# 0    64902
# Name: count, dtype: int64

# %%
academic_work_impact=df["academic_work_impact"]
academic_work_impact[df["addicted_label"]==1].value_counts()
# Out:
# academic_work_impact
# 1    265377
# 0    225097
# Name: count, dtype: int64

# %%
#weekend addiction has more relation to daily screen time
work_study_hours=df["work_study_hours"]
work_study_hours[df["addicted_label"]==0].value_counts()
# Out:
# work_study_hours
# 2.40    15383
# 1.77      969
# 1.27      962
# 1.29      958
# 1.53      902
#         ...
# 5.94        1
# 5.36        1
# 5.92        1
# 5.32        1
# 6.00        1
# Name: count, Length: 593, dtype: int64
